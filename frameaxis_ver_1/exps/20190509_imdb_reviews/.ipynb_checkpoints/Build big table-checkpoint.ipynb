# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, '../../libs/semaxis')
from semaxis import CoreUtil
from semaxis import SemAxis
import pandas as pd
import logging
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(name)-12s %(levelname)-8s %(message)s',
                    datefmt="%Y-%m-%d %H:%M:%S")
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# %%
df = pd.read_csv("bygenre_imdb_movie_reviews_by_sentence.tsv", sep="\t", quoting=3)
df.head()
# Out:
#     genre  rating                                             review
# 0  Comedy       9  Imagine a movie where Joe Piscopo is actually ...
# 1  Comedy       9              Maureen Stapleton is a scene stealer.
# 2  Comedy       9        The Moroni character is an absolute scream.
# 3  Comedy       9                                     Watch for Alan
# 4  Comedy       9                             "The Skipper" Hale jr.

# %%
df['genre'].value_counts()
# Out:
# Drama          28561
# Comedy         22042
# Action         11082
# Horror         10343
# Romance        10052
# Crime           9429
# Thriller        8738
# Adventure       7366
# Fantasy         5083
# Sci-Fi          4780
# Mystery         4317
# Family          3823
# Biography       2284
# Animation       2260
# Music           2071
# Documentary     1932
# History         1532
# War             1517
# Musical         1481
# Sport           1036
# Short           1012
# Western          985
# Film-Noir        414
# Reality-TV       241
# Adult            123
# Talk-Show         85
# \N                85
# Game-Show         78
# News              20
# Name: genre, dtype: int64

# %%
# %%time
sa = SemAxis(CoreUtil.load_embedding("../../data/embeddings/glove.840B.300d.w2vformat.txt", is_binary=False), 
               axes_str=CoreUtil.load_wordnet_antonyms_axes())
# Out:
# 2019-05-10 00:35:36 gensim.models.utils_any2vec INFO     loading projection weights from ../../data/embeddings/glove.840B.300d.w2vformat.txt
# 2019-05-10 00:36:09 gensim.models.utils_any2vec WARNING  duplicate word '����������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������' in ../../data/embeddings/glove.840B.300d.w2vformat.txt, ignoring all but first
# 2019-05-10 00:44:10 gensim.models.utils_any2vec INFO     duplicate words detected, shrinking matrix size from 2196017 to 2196016
# 2019-05-10 00:44:10 gensim.models.utils_any2vec INFO     loaded (2196016, 300) matrix from ../../data/embeddings/glove.840B.300d.w2vformat.txt
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('achlamydeous', 'chlamydeous') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'chlamydeous' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('apteral', 'peripteral') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'apteral' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('paintable', 'unpaintable') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unpaintable' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('ametropic', 'emmetropic') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'ametropic' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('endoergic', 'exoergic') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'exoergic' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('fueled', 'unfueled') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unfueled' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('statesmanlike', 'unstatesmanlike') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unstatesmanlike' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('columned', 'noncolumned') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'noncolumned' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('patronized', 'unpatronized') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unpatronized' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('playful', 'unplayful') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unplayful' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('multiparous', 'uniparous') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'uniparous' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('acarpelous', 'carpellate') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'carpellate' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('apocarpous', 'syncarpous') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'apocarpous' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('antrorse', 'retrorse') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'retrorse' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('acid-loving', 'alkaline-loving') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'alkaline-loving' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('exportable', 'unexportable') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unexportable' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('exaugural', 'inaugural') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'exaugural' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('unguiculate', 'ungulate') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unguiculate' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('heterodactyl', 'zygodactyl') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'heterodactyl' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('nonwoody', 'woody') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonwoody' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('high-sudsing', 'low-sudsing') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'high-sudsing' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('sessile', 'vagile') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'vagile' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('spaced', 'unspaced') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unspaced' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('nonterritorial', 'territorial') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonterritorial' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('anemophilous', 'entomophilous') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'entomophilous' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('liveried', 'unliveried') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unliveried' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('nonruminant', 'ruminant') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonruminant' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('double-barreled', 'single-barreled') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'single-barreled' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('unwebbed', 'webbed') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unwebbed' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('immanent', 'transeunt') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'transeunt' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('nonpasserine', 'passerine') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonpasserine' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('causative', 'noncausative') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'noncausative' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('bibbed', 'bibless') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'bibless' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('metamorphic', 'nonmetamorphic') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonmetamorphic' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('inquiring', 'uninquiring') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'uninquiring' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('balconied', 'unbalconied') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unbalconied' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('calcicolous', 'calcifugous') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'calcifugous' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('apetalous', 'petalous') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'petalous' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('nonsyllabic', 'syllabic') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonsyllabic' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('ambiversive', 'introversive') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'introversive' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('adsorbent', 'nonadsorbent') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonadsorbent' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('seductive', 'unseductive') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unseductive' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('perplexed', 'unperplexed') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unperplexed' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('cismontane', 'tramontane') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'cismontane' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('de-iodinating', 'iodinating') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'iodinating' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('loamless', 'loamy') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'loamless' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('nonsubmersible', 'submersible') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonsubmersible' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('arboreal', 'nonarboreal') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonarboreal' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('bellied', 'bellyless') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'bellyless' not in vocabulary"
# 2019-05-10 00:44:10 semaxis.semaxis ERROR    ('endocentric', 'exocentric') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# ...
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'noncivilized' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('fissile', 'nonfissile') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonfissile' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('starchless', 'starchy') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'starchless' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('ribbed', 'ribless') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'ribless' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('bordered', 'unbordered') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unbordered' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('heterocercal', 'homocercal') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'homocercal' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('rhythmical', 'unrhythmical') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unrhythmical' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('abactinal', 'actinal') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'actinal' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('catalectic', 'hypercatalectic') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'hypercatalectic' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('brainwashed', 'unbrainwashed') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unbrainwashed' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('injectable', 'uninjectable') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'uninjectable' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('laureled', 'unlaureled') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unlaureled' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('shrinkable', 'unshrinkable') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unshrinkable' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('aplacental', 'placental') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'aplacental' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('anaclinal', 'cataclinal') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'cataclinal' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('addicted', 'unaddicted') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unaddicted' not in vocabulary"
# 2019-05-10 00:44:11 semaxis.semaxis ERROR    ('asyndetic', 'syndetic') axis is not included in embedding
# Traceback (most recent call last):
#   File "../../libs/semaxis/semaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../../libs/semaxis/semaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 337, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 455, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py", line 452, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'syndetic' not in vocabulary"
# CPU times: user 8min 27s, sys: 5.2 s, total: 8min 32s
# Wall time: 8min 34s

# %%
df.shape
# Out:
# (142772, 3)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (142772, 3)

# %%
# df_1 = df.query('stars==1.0').sample(n=100000)
# df_1.head()

# %%
# df_5 = df.query('stars==5.0').sample(n=100000)
# df_5.head()

# %%
# df_s = df_1.append(df_5, ignore_index=True)

# %%
# df_s.to_csv("sampled_200k.tsv", sep="\t", index=False)

# %%
COLUMNS = [str(c) for c in sorted(sa.axes.keys()) if len(c) == 2]

with open("big_table_by_average.tsv", "w") as fo_a, open("big_table_by_kurtosis.tsv", "w") as fo_k:
    fo_a.write("genre\trating\treview\t{}\n".format("\t".join(COLUMNS)))
    fo_k.write("genre\trating\treview\t{}\n".format("\t".join(COLUMNS)))
    for loop_index, (row_index, row) in enumerate(df.iterrows()):
        if loop_index % (1000) == 0:
            logger.info(loop_index)
        try:
            _, mean, kurtosis = sa.compute_document_mean_kurtosis_with_tf([row['review']], min_freq = 1)
        except:
            continue

        fo_a.write("{}\t{}\t{}\t{}\n".format(row['genre'], row['rating'], row['review'], "\t".join([str(v) for v in mean])))
        fo_k.write("{}\t{}\t{}\t{}\n".format(row['genre'], row['rating'], row['review'], "\t".join([str(v) for v in kurtosis])))
# Out:
# 2019-05-10 00:44:11 __main__     INFO     0
# 2019-05-10 00:44:49 __main__     INFO     1000
# 2019-05-10 00:45:29 __main__     INFO     2000
# 2019-05-10 00:46:12 __main__     INFO     3000
# 2019-05-10 00:46:55 __main__     INFO     4000
# 2019-05-10 00:47:38 __main__     INFO     5000
# 2019-05-10 00:48:20 __main__     INFO     6000
# 2019-05-10 00:49:02 __main__     INFO     7000
# 2019-05-10 00:49:43 __main__     INFO     8000
# 2019-05-10 00:50:24 __main__     INFO     9000
# 2019-05-10 00:51:17 __main__     INFO     10000
# 2019-05-10 00:51:59 __main__     INFO     11000
# 2019-05-10 00:52:38 __main__     INFO     12000
# 2019-05-10 00:53:21 __main__     INFO     13000
# 2019-05-10 00:54:02 __main__     INFO     14000
# 2019-05-10 00:54:41 __main__     INFO     15000
# 2019-05-10 00:55:23 __main__     INFO     16000
# 2019-05-10 00:56:07 __main__     INFO     17000
# 2019-05-10 00:56:50 __main__     INFO     18000
# 2019-05-10 00:57:31 __main__     INFO     19000
# 2019-05-10 00:58:12 __main__     INFO     20000
# 2019-05-10 00:58:52 __main__     INFO     21000
# 2019-05-10 00:59:35 __main__     INFO     22000
# 2019-05-10 01:00:17 __main__     INFO     23000
# 2019-05-10 01:00:58 __main__     INFO     24000
# 2019-05-10 01:01:37 __main__     INFO     25000
# 2019-05-10 01:02:20 __main__     INFO     26000
# 2019-05-10 01:03:02 __main__     INFO     27000
# 2019-05-10 01:03:44 __main__     INFO     28000
# 2019-05-10 01:04:25 __main__     INFO     29000
# 2019-05-10 01:05:05 __main__     INFO     30000
# 2019-05-10 01:05:45 __main__     INFO     31000
# 2019-05-10 01:06:23 __main__     INFO     32000
# 2019-05-10 01:07:03 __main__     INFO     33000
# 2019-05-10 01:07:44 __main__     INFO     34000
# 2019-05-10 01:08:23 __main__     INFO     35000
# 2019-05-10 01:09:05 __main__     INFO     36000
# 2019-05-10 01:09:51 __main__     INFO     37000
# 2019-05-10 01:10:32 __main__     INFO     38000
# 2019-05-10 01:11:11 __main__     INFO     39000
# 2019-05-10 01:11:52 __main__     INFO     40000
# 2019-05-10 01:12:35 __main__     INFO     41000
# 2019-05-10 01:13:17 __main__     INFO     42000
# 2019-05-10 01:13:54 __main__     INFO     43000
# 2019-05-10 01:14:39 __main__     INFO     44000
# 2019-05-10 01:15:35 __main__     INFO     45000
# 2019-05-10 01:16:19 __main__     INFO     46000
# 2019-05-10 01:17:02 __main__     INFO     47000
# 2019-05-10 01:17:50 __main__     INFO     48000
# 2019-05-10 01:18:35 __main__     INFO     49000
# 2019-05-10 01:19:19 __main__     INFO     50000
# 2019-05-10 01:20:02 __main__     INFO     51000
# 2019-05-10 01:20:46 __main__     INFO     52000
# 2019-05-10 01:21:29 __main__     INFO     53000
# 2019-05-10 01:22:13 __main__     INFO     54000
# 2019-05-10 01:22:56 __main__     INFO     55000
# 2019-05-10 01:23:39 __main__     INFO     56000
# 2019-05-10 01:24:22 __main__     INFO     57000
# 2019-05-10 01:25:05 __main__     INFO     58000
# 2019-05-10 01:25:49 __main__     INFO     59000
# 2019-05-10 01:26:35 __main__     INFO     60000
# 2019-05-10 01:27:18 __main__     INFO     61000
# 2019-05-10 01:28:01 __main__     INFO     62000
# 2019-05-10 01:28:43 __main__     INFO     63000
# 2019-05-10 01:29:27 __main__     INFO     64000
# 2019-05-10 01:30:14 __main__     INFO     65000
# 2019-05-10 01:30:59 __main__     INFO     66000
# 2019-05-10 01:31:47 __main__     INFO     67000
# 2019-05-10 01:32:36 __main__     INFO     68000
# 2019-05-10 01:33:24 __main__     INFO     69000
# 2019-05-10 01:34:10 __main__     INFO     70000
# 2019-05-10 01:34:55 __main__     INFO     71000
# 2019-05-10 01:35:40 __main__     INFO     72000
# 2019-05-10 01:36:26 __main__     INFO     73000
# 2019-05-10 01:37:11 __main__     INFO     74000
# 2019-05-10 01:37:57 __main__     INFO     75000
# 2019-05-10 01:38:49 __main__     INFO     76000
# 2019-05-10 01:39:44 __main__     INFO     77000
# 2019-05-10 01:40:31 __main__     INFO     78000
# 2019-05-10 01:41:16 __main__     INFO     79000
# 2019-05-10 01:42:14 __main__     INFO     80000
# 2019-05-10 01:43:03 __main__     INFO     81000
# 2019-05-10 01:43:45 __main__     INFO     82000
# 2019-05-10 01:44:26 __main__     INFO     83000
# 2019-05-10 01:45:17 __main__     INFO     84000
# 2019-05-10 01:46:06 __main__     INFO     85000
# 2019-05-10 01:46:53 __main__     INFO     86000
# 2019-05-10 01:47:42 __main__     INFO     87000
# 2019-05-10 01:48:30 __main__     INFO     88000
# 2019-05-10 01:49:19 __main__     INFO     89000
# 2019-05-10 01:50:07 __main__     INFO     90000
# 2019-05-10 01:50:54 __main__     INFO     91000
# 2019-05-10 01:51:38 __main__     INFO     92000
# 2019-05-10 01:52:21 __main__     INFO     93000
# 2019-05-10 01:53:09 __main__     INFO     94000
# 2019-05-10 01:53:59 __main__     INFO     95000
# 2019-05-10 01:54:48 __main__     INFO     96000
# 2019-05-10 01:55:37 __main__     INFO     97000
# 2019-05-10 01:56:35 __main__     INFO     98000
# 2019-05-10 01:57:30 __main__     INFO     99000
# 2019-05-10 01:58:22 __main__     INFO     100000
# 2019-05-10 01:59:17 __main__     INFO     101000
# 2019-05-10 02:00:10 __main__     INFO     102000
# 2019-05-10 02:01:01 __main__     INFO     103000
# 2019-05-10 02:01:50 __main__     INFO     104000
# 2019-05-10 02:02:40 __main__     INFO     105000
# 2019-05-10 02:03:31 __main__     INFO     106000
# 2019-05-10 02:04:22 __main__     INFO     107000
# 2019-05-10 02:05:10 __main__     INFO     108000
# 2019-05-10 02:06:10 __main__     INFO     109000
# 2019-05-10 02:07:03 __main__     INFO     110000
# 2019-05-10 02:07:59 __main__     INFO     111000
# 2019-05-10 02:08:47 __main__     INFO     112000
# 2019-05-10 02:09:42 __main__     INFO     113000
# 2019-05-10 02:10:34 __main__     INFO     114000
# 2019-05-10 02:11:23 __main__     INFO     115000
# 2019-05-10 02:12:10 __main__     INFO     116000
# 2019-05-10 02:13:03 __main__     INFO     117000
# 2019-05-10 02:13:53 __main__     INFO     118000
# 2019-05-10 02:14:40 __main__     INFO     119000
# 2019-05-10 02:15:30 __main__     INFO     120000
# 2019-05-10 02:16:18 __main__     INFO     121000
# 2019-05-10 02:17:05 __main__     INFO     122000
# 2019-05-10 02:17:51 __main__     INFO     123000
# 2019-05-10 02:18:35 __main__     INFO     124000
# 2019-05-10 02:19:21 __main__     INFO     125000
# 2019-05-10 02:20:22 __main__     INFO     126000
# 2019-05-10 02:21:07 __main__     INFO     127000
# 2019-05-10 02:21:59 __main__     INFO     128000
# 2019-05-10 02:22:47 __main__     INFO     129000
# 2019-05-10 02:23:35 __main__     INFO     130000
# 2019-05-10 02:24:23 __main__     INFO     131000
# 2019-05-10 02:25:08 __main__     INFO     132000
# 2019-05-10 02:25:55 __main__     INFO     133000
# 2019-05-10 02:26:40 __main__     INFO     134000
# 2019-05-10 02:27:26 __main__     INFO     135000
# 2019-05-10 02:28:19 __main__     INFO     136000
# 2019-05-10 02:29:08 __main__     INFO     137000
# 2019-05-10 02:29:52 __main__     INFO     138000
# 2019-05-10 02:30:40 __main__     INFO     139000
# 2019-05-10 02:31:30 __main__     INFO     140000
# 2019-05-10 02:32:21 __main__     INFO     141000
# 2019-05-10 02:33:12 __main__     INFO     142000

# %% [markdown]
# # kurtosis with corpus mean

# %%
# test
import numpy as np
df_corpus = pd.read_csv("big_table_by_average.tsv", sep="\t")
corpus_mean = np.mean(df_corpus.drop(
    columns=[c for c in df_corpus.columns if '(' not in c]).as_matrix(), axis=0)
corpus_mean
# Out:
# /Users/haewoon/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """
# array([ 0.00978353, -0.09955554,  0.11035769, ...,  0.0632974 ,
#        -0.1242091 ,  0.02102767])

# %%
COLUMNS = [str(c) for c in sorted(sa.axes.keys()) if len(c) == 2]

with open("big_table_by_kurtosis_with_corpus_mean.tsv", "w") as fo_k:
    fo_k.write("genre\trating\treview\t{}\n".format("\t".join(COLUMNS)))
#     df_corpus = pd.read_csv("big_table_200k_by_average.tsv", sep="\t")
#     corpus_mean = np.mean(df_corpus.drop(
#         columns=[c for c in df_corpus.columns if '(' not in c]).as_matrix(), axis=0)
    for loop_index, (row_index, row) in enumerate(df.iterrows()):
        if loop_index % (1000) == 0:
            logger.info(loop_index)
        try:
            _, kurtosis = sa.compute_document_kurtosis_with_tf([row['review']], corpus_mean, min_freq = 1)  
        except:
            continue

        fo_k.write("{}\t{}\t{}\t{}\n".format(row['genre'], row['rating'], row['review'], "\t".join([str(v) for v in kurtosis[0]])))
#         break
# Out:
# 2019-05-10 08:45:52 __main__     INFO     0
# 2019-05-10 08:46:34 __main__     INFO     1000
# 2019-05-10 08:47:19 __main__     INFO     2000
# 2019-05-10 08:48:09 __main__     INFO     3000
# 2019-05-10 08:48:52 __main__     INFO     4000
# 2019-05-10 08:49:35 __main__     INFO     5000
# 2019-05-10 08:50:17 __main__     INFO     6000
# 2019-05-10 08:50:59 __main__     INFO     7000
# 2019-05-10 08:51:39 __main__     INFO     8000
# 2019-05-10 08:52:23 __main__     INFO     9000
# 2019-05-10 08:53:15 __main__     INFO     10000
# 2019-05-10 08:54:15 __main__     INFO     11000
# 2019-05-10 08:55:18 __main__     INFO     12000
# 2019-05-10 08:56:21 __main__     INFO     13000
# 2019-05-10 08:57:07 __main__     INFO     14000
# 2019-05-10 08:57:49 __main__     INFO     15000
# 2019-05-10 08:58:35 __main__     INFO     16000
# 2019-05-10 08:59:19 __main__     INFO     17000
# 2019-05-10 09:00:00 __main__     INFO     18000
# 2019-05-10 09:00:44 __main__     INFO     19000
# 2019-05-10 09:01:25 __main__     INFO     20000
# 2019-05-10 09:02:03 __main__     INFO     21000
# 2019-05-10 09:02:45 __main__     INFO     22000
# 2019-05-10 09:03:26 __main__     INFO     23000
# 2019-05-10 09:04:09 __main__     INFO     24000
# 2019-05-10 09:04:47 __main__     INFO     25000
# 2019-05-10 09:05:26 __main__     INFO     26000
# 2019-05-10 09:06:06 __main__     INFO     27000
# 2019-05-10 09:06:46 __main__     INFO     28000
# 2019-05-10 09:07:30 __main__     INFO     29000
# 2019-05-10 09:08:10 __main__     INFO     30000
# 2019-05-10 09:08:49 __main__     INFO     31000
# 2019-05-10 09:09:29 __main__     INFO     32000
# 2019-05-10 09:10:12 __main__     INFO     33000
# 2019-05-10 09:10:53 __main__     INFO     34000
# 2019-05-10 09:11:36 __main__     INFO     35000
# 2019-05-10 09:12:16 __main__     INFO     36000
# 2019-05-10 09:13:00 __main__     INFO     37000
# 2019-05-10 09:13:40 __main__     INFO     38000
# 2019-05-10 09:14:23 __main__     INFO     39000
# 2019-05-10 09:15:03 __main__     INFO     40000
# 2019-05-10 09:15:43 __main__     INFO     41000
# 2019-05-10 09:16:24 __main__     INFO     42000
# 2019-05-10 09:17:10 __main__     INFO     43000
# 2019-05-10 09:17:58 __main__     INFO     44000
# 2019-05-10 09:18:54 __main__     INFO     45000
# 2019-05-10 09:19:40 __main__     INFO     46000
# 2019-05-10 09:20:22 __main__     INFO     47000
# 2019-05-10 09:21:12 __main__     INFO     48000
# 2019-05-10 09:21:58 __main__     INFO     49000
# 2019-05-10 09:22:45 __main__     INFO     50000
# 2019-05-10 09:23:50 __main__     INFO     51000
# 2019-05-10 09:24:38 __main__     INFO     52000
# 2019-05-10 09:25:21 __main__     INFO     53000
# 2019-05-10 09:26:04 __main__     INFO     54000
# 2019-05-10 09:26:47 __main__     INFO     55000
# 2019-05-10 09:27:36 __main__     INFO     56000
# 2019-05-10 09:28:18 __main__     INFO     57000
# 2019-05-10 09:29:01 __main__     INFO     58000
# 2019-05-10 09:29:44 __main__     INFO     59000
# 2019-05-10 09:30:27 __main__     INFO     60000
# 2019-05-10 09:31:09 __main__     INFO     61000
# 2019-05-10 09:31:53 __main__     INFO     62000
# 2019-05-10 09:32:35 __main__     INFO     63000
# 2019-05-10 09:33:18 __main__     INFO     64000
# 2019-05-10 09:34:01 __main__     INFO     65000
# 2019-05-10 09:34:43 __main__     INFO     66000
# 2019-05-10 09:35:27 __main__     INFO     67000
# 2019-05-10 09:36:10 __main__     INFO     68000
# 2019-05-10 09:36:53 __main__     INFO     69000
# 2019-05-10 09:37:34 __main__     INFO     70000
# 2019-05-10 09:38:17 __main__     INFO     71000
# 2019-05-10 09:39:00 __main__     INFO     72000
# 2019-05-10 09:39:44 __main__     INFO     73000
# 2019-05-10 09:40:27 __main__     INFO     74000
# 2019-05-10 09:41:11 __main__     INFO     75000
# 2019-05-10 09:41:55 __main__     INFO     76000
# 2019-05-10 09:42:38 __main__     INFO     77000
# 2019-05-10 09:43:21 __main__     INFO     78000
# 2019-05-10 09:44:04 __main__     INFO     79000
# 2019-05-10 09:44:48 __main__     INFO     80000
# 2019-05-10 09:45:32 __main__     INFO     81000
# 2019-05-10 09:46:16 __main__     INFO     82000
# 2019-05-10 09:46:59 __main__     INFO     83000
# 2019-05-10 09:47:43 __main__     INFO     84000
# 2019-05-10 09:48:27 __main__     INFO     85000
# 2019-05-10 09:49:11 __main__     INFO     86000
# 2019-05-10 09:49:56 __main__     INFO     87000
# 2019-05-10 09:50:39 __main__     INFO     88000
# 2019-05-10 09:51:24 __main__     INFO     89000
# 2019-05-10 09:52:07 __main__     INFO     90000
# 2019-05-10 09:52:51 __main__     INFO     91000
# 2019-05-10 09:53:34 __main__     INFO     92000
# 2019-05-10 09:54:17 __main__     INFO     93000
# 2019-05-10 09:55:01 __main__     INFO     94000
# 2019-05-10 09:55:44 __main__     INFO     95000
# 2019-05-10 09:56:28 __main__     INFO     96000
# 2019-05-10 09:57:12 __main__     INFO     97000
# 2019-05-10 09:57:57 __main__     INFO     98000
# 2019-05-10 09:58:40 __main__     INFO     99000
# 2019-05-10 09:59:23 __main__     INFO     100000
# 2019-05-10 10:00:06 __main__     INFO     101000
# 2019-05-10 10:00:52 __main__     INFO     102000
# 2019-05-10 10:01:47 __main__     INFO     103000
# 2019-05-10 10:02:38 __main__     INFO     104000
# 2019-05-10 10:03:31 __main__     INFO     105000
# 2019-05-10 10:04:19 __main__     INFO     106000
# 2019-05-10 10:05:03 __main__     INFO     107000
# 2019-05-10 10:05:47 __main__     INFO     108000
# 2019-05-10 10:06:33 __main__     INFO     109000
# 2019-05-10 10:07:18 __main__     INFO     110000
# 2019-05-10 10:08:01 __main__     INFO     111000
# 2019-05-10 10:08:43 __main__     INFO     112000
# 2019-05-10 10:09:26 __main__     INFO     113000
# 2019-05-10 10:10:16 __main__     INFO     114000
# 2019-05-10 10:11:06 __main__     INFO     115000
# 2019-05-10 10:11:58 __main__     INFO     116000
# 2019-05-10 10:12:52 __main__     INFO     117000
# 2019-05-10 10:13:46 __main__     INFO     118000
# 2019-05-10 10:14:38 __main__     INFO     119000
# 2019-05-10 10:15:22 __main__     INFO     120000
# 2019-05-10 10:16:04 __main__     INFO     121000
# 2019-05-10 10:17:00 __main__     INFO     122000
# 2019-05-10 10:17:50 __main__     INFO     123000
# 2019-05-10 10:18:39 __main__     INFO     124000
# 2019-05-10 10:19:27 __main__     INFO     125000
# 2019-05-10 10:20:11 __main__     INFO     126000
# 2019-05-10 10:20:58 __main__     INFO     127000
# 2019-05-10 10:21:48 __main__     INFO     128000
# 2019-05-10 10:22:30 __main__     INFO     129000
# 2019-05-10 10:23:16 __main__     INFO     130000
# 2019-05-10 10:24:01 __main__     INFO     131000
# 2019-05-10 10:24:49 __main__     INFO     132000
# 2019-05-10 10:25:36 __main__     INFO     133000
# 2019-05-10 10:26:25 __main__     INFO     134000
# 2019-05-10 10:27:14 __main__     INFO     135000
# 2019-05-10 10:28:02 __main__     INFO     136000
# 2019-05-10 10:28:49 __main__     INFO     137000
# 2019-05-10 10:29:36 __main__     INFO     138000
# 2019-05-10 10:30:20 __main__     INFO     139000
# 2019-05-10 10:31:13 __main__     INFO     140000
# 2019-05-10 10:32:01 __main__     INFO     141000
# 2019-05-10 10:32:45 __main__     INFO     142000

# %% [markdown]
# # second moment

# %%
COLUMNS = [str(c) for c in sorted(sa.axes.keys()) if len(c) == 2]

with open("big_table_by_second_moment_with_corpus_mean.tsv", "w") as fo_k:
    fo_k.write("genre\trating\treview\t{}\n".format("\t".join(COLUMNS)))
#     df_corpus = pd.read_csv("big_table_200k_by_average.tsv", sep="\t")
#     corpus_mean = np.mean(df_corpus.drop(
#         columns=[c for c in df_corpus.columns if '(' not in c]).as_matrix(), axis=0)
    for loop_index, (row_index, row) in enumerate(df.iterrows()):
        if loop_index % (1000) == 0:
            logger.info(loop_index)
        try:
            sm = sa.compute_document_second_moment_with_tf([row['review']], corpus_mean, min_freq = 1)  
        except:
            continue

        fo_k.write("{}\t{}\t{}\t{}\n".format(row['genre'], row['rating'], row['review'], "\t".join([str(v) for v in sm[0]])))
#         break
# Out:
# 2019-05-10 02:37:48 __main__     INFO     0
# 2019-05-10 02:38:24 __main__     INFO     1000
# 2019-05-10 02:39:01 __main__     INFO     2000
# 2019-05-10 02:39:38 __main__     INFO     3000
# 2019-05-10 02:40:17 __main__     INFO     4000
# 2019-05-10 02:40:54 __main__     INFO     5000
# 2019-05-10 02:41:30 __main__     INFO     6000
# 2019-05-10 02:42:06 __main__     INFO     7000
# 2019-05-10 02:42:42 __main__     INFO     8000
# 2019-05-10 02:43:19 __main__     INFO     9000
# 2019-05-10 02:43:54 __main__     INFO     10000
# 2019-05-10 02:44:30 __main__     INFO     11000
# 2019-05-10 02:45:06 __main__     INFO     12000
# 2019-05-10 02:45:42 __main__     INFO     13000
# 2019-05-10 02:46:18 __main__     INFO     14000
# 2019-05-10 02:46:55 __main__     INFO     15000
# 2019-05-10 02:47:32 __main__     INFO     16000
# 2019-05-10 02:48:09 __main__     INFO     17000
# 2019-05-10 02:48:44 __main__     INFO     18000
# 2019-05-10 02:49:20 __main__     INFO     19000
# 2019-05-10 02:49:56 __main__     INFO     20000
# 2019-05-10 02:50:31 __main__     INFO     21000
# 2019-05-10 02:51:09 __main__     INFO     22000
# 2019-05-10 02:51:45 __main__     INFO     23000
# 2019-05-10 02:52:21 __main__     INFO     24000
# 2019-05-10 02:52:58 __main__     INFO     25000
# 2019-05-10 02:53:34 __main__     INFO     26000
# 2019-05-10 02:54:11 __main__     INFO     27000
# 2019-05-10 02:54:48 __main__     INFO     28000
# 2019-05-10 02:55:24 __main__     INFO     29000
# 2019-05-10 02:56:06 __main__     INFO     30000
# 2019-05-10 02:56:49 __main__     INFO     31000
# 2019-05-10 02:57:34 __main__     INFO     32000
# 2019-05-10 02:58:16 __main__     INFO     33000
# 2019-05-10 02:58:55 __main__     INFO     34000
# 2019-05-10 02:59:34 __main__     INFO     35000
# 2019-05-10 03:00:11 __main__     INFO     36000
# 2019-05-10 03:00:54 __main__     INFO     37000
# 2019-05-10 03:01:36 __main__     INFO     38000
# 2019-05-10 03:02:17 __main__     INFO     39000
# 2019-05-10 03:03:01 __main__     INFO     40000
# 2019-05-10 03:03:45 __main__     INFO     41000
# 2019-05-10 03:04:25 __main__     INFO     42000
# 2019-05-10 03:05:07 __main__     INFO     43000
# 2019-05-10 03:05:45 __main__     INFO     44000
# 2019-05-10 03:06:29 __main__     INFO     45000
# 2019-05-10 03:07:09 __main__     INFO     46000
# 2019-05-10 03:07:47 __main__     INFO     47000
# 2019-05-10 03:08:24 __main__     INFO     48000
# 2019-05-10 03:09:04 __main__     INFO     49000
# 2019-05-10 03:09:42 __main__     INFO     50000
# 2019-05-10 03:10:17 __main__     INFO     51000
# 2019-05-10 03:11:01 __main__     INFO     52000
# 2019-05-10 03:11:45 __main__     INFO     53000
# 2019-05-10 03:12:27 __main__     INFO     54000
# 2019-05-10 03:13:05 __main__     INFO     55000
# 2019-05-10 03:13:41 __main__     INFO     56000
# 2019-05-10 03:14:17 __main__     INFO     57000
# 2019-05-10 03:14:53 __main__     INFO     58000
# 2019-05-10 03:15:29 __main__     INFO     59000
# 2019-05-10 03:16:06 __main__     INFO     60000
# 2019-05-10 03:16:41 __main__     INFO     61000
# 2019-05-10 03:17:16 __main__     INFO     62000
# 2019-05-10 03:17:51 __main__     INFO     63000
# 2019-05-10 03:18:27 __main__     INFO     64000
# 2019-05-10 03:19:04 __main__     INFO     65000
# 2019-05-10 03:19:40 __main__     INFO     66000
# 2019-05-10 03:20:17 __main__     INFO     67000
# 2019-05-10 03:20:57 __main__     INFO     68000
# 2019-05-10 03:21:37 __main__     INFO     69000
# 2019-05-10 03:22:13 __main__     INFO     70000
# 2019-05-10 03:22:51 __main__     INFO     71000
# 2019-05-10 03:23:30 __main__     INFO     72000
# 2019-05-10 03:24:09 __main__     INFO     73000
# 2019-05-10 03:24:45 __main__     INFO     74000
# 2019-05-10 03:25:22 __main__     INFO     75000
# 2019-05-10 03:25:59 __main__     INFO     76000
# 2019-05-10 03:26:35 __main__     INFO     77000
# 2019-05-10 03:27:11 __main__     INFO     78000
# 2019-05-10 03:27:46 __main__     INFO     79000
# 2019-05-10 03:28:25 __main__     INFO     80000
# 2019-05-10 03:29:02 __main__     INFO     81000
# 2019-05-10 03:29:43 __main__     INFO     82000
# 2019-05-10 03:30:19 __main__     INFO     83000
# 2019-05-10 03:30:55 __main__     INFO     84000
# 2019-05-10 03:31:34 __main__     INFO     85000
# 2019-05-10 03:32:16 __main__     INFO     86000
# 2019-05-10 03:32:53 __main__     INFO     87000
# 2019-05-10 03:33:30 __main__     INFO     88000
# 2019-05-10 03:34:06 __main__     INFO     89000
# 2019-05-10 03:34:41 __main__     INFO     90000
# 2019-05-10 03:35:18 __main__     INFO     91000
# 2019-05-10 03:35:54 __main__     INFO     92000
# 2019-05-10 03:36:30 __main__     INFO     93000
# 2019-05-10 03:37:07 __main__     INFO     94000
# 2019-05-10 03:37:43 __main__     INFO     95000
# 2019-05-10 03:38:19 __main__     INFO     96000
# 2019-05-10 03:38:55 __main__     INFO     97000
# 2019-05-10 03:39:32 __main__     INFO     98000
# 2019-05-10 03:40:10 __main__     INFO     99000
# 2019-05-10 03:40:46 __main__     INFO     100000
# 2019-05-10 03:41:22 __main__     INFO     101000
# 2019-05-10 03:41:58 __main__     INFO     102000
# 2019-05-10 03:42:35 __main__     INFO     103000
# 2019-05-10 03:43:11 __main__     INFO     104000
# 2019-05-10 03:43:46 __main__     INFO     105000
# 2019-05-10 03:44:23 __main__     INFO     106000
# 2019-05-10 03:44:59 __main__     INFO     107000
# 2019-05-10 03:45:35 __main__     INFO     108000
# 2019-05-10 03:46:11 __main__     INFO     109000
# 2019-05-10 03:46:47 __main__     INFO     110000
# 2019-05-10 03:47:22 __main__     INFO     111000
# 2019-05-10 03:47:52 __main__     INFO     112000
# 2019-05-10 03:48:23 __main__     INFO     113000
# 2019-05-10 03:48:54 __main__     INFO     114000
# 2019-05-10 03:49:24 __main__     INFO     115000
# 2019-05-10 03:49:54 __main__     INFO     116000
# 2019-05-10 03:50:24 __main__     INFO     117000
# 2019-05-10 03:50:55 __main__     INFO     118000
# 2019-05-10 03:51:26 __main__     INFO     119000
# 2019-05-10 03:51:57 __main__     INFO     120000
# 2019-05-10 03:52:27 __main__     INFO     121000
# 2019-05-10 03:52:58 __main__     INFO     122000
# 2019-05-10 03:53:28 __main__     INFO     123000
# 2019-05-10 03:53:58 __main__     INFO     124000
# 2019-05-10 03:54:28 __main__     INFO     125000
# 2019-05-10 03:54:58 __main__     INFO     126000
# 2019-05-10 03:55:28 __main__     INFO     127000
# 2019-05-10 03:55:58 __main__     INFO     128000
# 2019-05-10 03:56:29 __main__     INFO     129000
# 2019-05-10 03:57:00 __main__     INFO     130000
# 2019-05-10 03:57:30 __main__     INFO     131000
# 2019-05-10 03:58:00 __main__     INFO     132000
# 2019-05-10 03:58:30 __main__     INFO     133000
# 2019-05-10 03:59:01 __main__     INFO     134000
# 2019-05-10 03:59:32 __main__     INFO     135000
# 2019-05-10 04:00:03 __main__     INFO     136000
# 2019-05-10 04:00:33 __main__     INFO     137000
# 2019-05-10 04:01:03 __main__     INFO     138000
# 2019-05-10 04:01:34 __main__     INFO     139000
# 2019-05-10 04:02:04 __main__     INFO     140000
# 2019-05-10 04:02:35 __main__     INFO     141000
# 2019-05-10 04:03:04 __main__     INFO     142000
