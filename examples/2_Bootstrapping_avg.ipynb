# %%
import pandas as pd
import glob
import logging
import os
import gc
import numpy as np

# %%
logging.basicConfig(level=logging.DEBUG,
                    format='%(asctime)s %(name)-12s %(levelname)-8s %(message)s',
                    datefmt="%Y-%m-%d %H:%M:%S")
logger = logging.getLogger(__name__)

# %% [markdown]
# # Memory-efficient version (numpy)

# %%
N = 1000
mode = "average"
logger.info(mode)
try:
    os.mkdir(mode)
except:
    pass

df = pd.read_csv("big_table_by_{}.tsv".format(mode), sep="\t").dropna()
COLUMNS = [c for c in df.columns if '(' in c]
len(COLUMNS)
# Out:
# 2020-04-18 16:34:07 __main__     INFO     average
# 1621

# %%
df.head()
# Out:
#     genre  rating                                             review  \
# 0  Comedy       9  Imagine a movie where Joe Piscopo is actually ...
# 1  Comedy       9              Maureen Stapleton is a scene stealer.
# 2  Comedy       9        The Moroni character is an absolute scream.
# 3  Comedy       9                                     Watch for Alan
# 4  Comedy       9                               The Skipper Hale jr.
#
#    ('abaxial', 'adaxial')  ('able', 'unable')  ('abnormal', 'normal')  \
# 0               -0.007778           -0.120067                0.149650
# 1               -0.018657            0.027373               -0.014663
# 2               -0.008353            0.003532                0.024841
# 3               -0.022095           -0.011114                0.065992
# 4                0.022302            0.069319                0.041268
#
#    ('aboral', 'oral')  ('abridged', 'unabridged')  ('absent', 'present')  \
# 0            0.226433                   -0.041310               0.054527
# 1           -0.020489                    0.071209              -0.054418
# 2            0.071209                    0.034671              -0.033799
# 3            0.092812                    0.027358               0.012269
# 4            0.004172                    0.031741              -0.096760
#
#    ('absolute', 'relative')  ...  ('unwritten', 'written')  \
# 0                 -0.087520  ...                  0.096133
# 1                 -0.036486  ...                 -0.078343
# 2                 -0.181211  ...                 -0.043274
# 3                 -0.078474  ...                 -0.009674
# 4                 -0.025746  ...                 -0.064106
#
#    ('useful', 'useless')  ('valuable', 'worthless')  ('vernal', 'wintry')  \
# 0               0.063818                   0.046937              0.056813
# 1               0.064649                   0.035512             -0.031323
# 2               0.103763                   0.081682              0.019105
# 3               0.099940                   0.054162              0.003347
# 4               0.061775                  -0.010745             -0.027684
#
#    ('virtuous', 'wicked')  ('waning', 'waxing')  ('weedless', 'weedy')  \
# 0                0.151531              0.039405               0.088752
# 1                0.079253              0.018877               0.026791
# 2                0.058446              0.004526               0.044056
# 3                0.122735             -0.013558               0.046315
# 4                0.069202             -0.018742               0.044781
#
#    ('weightless', 'weighty')  ('winged', 'wingless')  ('wired', 'wireless')
# 0                   0.044839               -0.161155               0.010192
# 1                  -0.031148               -0.033963              -0.012616
# 2                   0.014842               -0.116878              -0.010964
# 3                  -0.031949               -0.124008               0.027184
# 4                  -0.024739               -0.057287              -0.001812
#
# [5 rows x 1624 columns]

# %%
for genre, a_count in df['genre'].value_counts().iteritems():
    if a_count < 1000:
        continue

    logger.info("{}...".format(genre))
    with open("{}/bootstrap_{}_average_by_genre.tsv".format(mode, genre), "w") as fo:
        fo.write("{}\n".format("\t".join(COLUMNS)))
        A = df.drop(columns=[c for c in df.columns if '(' not in c]).values

        for i in range(N):
            if i % 100 == 0:
                logger.info(i)
            fmean = np.mean(A[np.random.choice(A.shape[0], a_count, replace=False), :], axis=0)
            fo.write("{}\n".format("\t".join([str(v) for v in (fmean)])))
# Out:
# 2020-04-18 16:34:10 __main__     INFO     Drama...
# 2020-04-18 16:34:10 __main__     INFO     0
# 2020-04-18 16:34:14 __main__     INFO     100
# 2020-04-18 16:34:18 __main__     INFO     200
# 2020-04-18 16:34:22 __main__     INFO     300
# 2020-04-18 16:34:26 __main__     INFO     400
# 2020-04-18 16:34:30 __main__     INFO     500
# 2020-04-18 16:34:35 __main__     INFO     600
# 2020-04-18 16:34:40 __main__     INFO     700
# 2020-04-18 16:34:46 __main__     INFO     800
# 2020-04-18 16:34:51 __main__     INFO     900
# 2020-04-18 16:34:56 __main__     INFO     Comedy...
# 2020-04-18 16:34:56 __main__     INFO     0
# 2020-04-18 16:35:00 __main__     INFO     100
# 2020-04-18 16:35:04 __main__     INFO     200
# 2020-04-18 16:35:08 __main__     INFO     300
# 2020-04-18 16:35:12 __main__     INFO     400
# 2020-04-18 16:35:17 __main__     INFO     500
# 2020-04-18 16:35:20 __main__     INFO     600
# 2020-04-18 16:35:23 __main__     INFO     700
# 2020-04-18 16:35:26 __main__     INFO     800
# 2020-04-18 16:35:29 __main__     INFO     900
