# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, '../frameaxis')
from semaxis import CoreUtil
from semaxis import SemAxis
import pandas as pd
import logging
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(name)-12s %(levelname)-8s %(message)s',
                    datefmt="%Y-%m-%d %H:%M:%S")
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# %%
df = pd.read_csv("restaurant.tsv", sep="\t")

# %%
# %%time
sa = SemAxis(CoreUtil.load_embedding("../data/embeddings/glove.840B.300d.w2vformat.txt", is_binary=False), 
               axes_str=CoreUtil.load_wordnet_antonyms_axes())
# Out:
# 2021-11-23 21:40:44 gensim.models.utils_any2vec INFO     loading projection weights from ../data/embeddings/glove.840B.300d.w2vformat.txt
# 2021-11-23 21:41:01 gensim.models.utils_any2vec WARNING  duplicate word '����������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������' in word2vec file, ignoring all but first
# 2021-11-23 21:45:11 gensim.models.utils_any2vec INFO     duplicate words detected, shrinking matrix size from 2196017 to 2196016
# 2021-11-23 21:45:11 gensim.models.utils_any2vec INFO     loaded (2196016, 300) matrix from ../data/embeddings/glove.840B.300d.w2vformat.txt
# 2021-11-23 21:45:11 semaxis      ERROR    ('achlamydeous', 'chlamydeous') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'chlamydeous' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('apteral', 'peripteral') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'apteral' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('paintable', 'unpaintable') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unpaintable' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('ametropic', 'emmetropic') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'ametropic' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('endoergic', 'exoergic') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'exoergic' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('fueled', 'unfueled') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unfueled' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('statesmanlike', 'unstatesmanlike') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unstatesmanlike' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('columned', 'noncolumned') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'noncolumned' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('patronized', 'unpatronized') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unpatronized' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('playful', 'unplayful') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unplayful' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('multiparous', 'uniparous') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'uniparous' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('acarpelous', 'carpellate') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'carpellate' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('apocarpous', 'syncarpous') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'apocarpous' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('antrorse', 'retrorse') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'retrorse' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('acid-loving', 'alkaline-loving') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'alkaline-loving' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('exportable', 'unexportable') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unexportable' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('exaugural', 'inaugural') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'exaugural' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('unguiculate', 'ungulate') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unguiculate' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('heterodactyl', 'zygodactyl') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'heterodactyl' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('nonwoody', 'woody') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonwoody' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('high-sudsing', 'low-sudsing') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'high-sudsing' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('sessile', 'vagile') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'vagile' not in vocabulary"
# 2021-11-23 21:45:11 semaxis      ERROR    ('spaced', 'unspaced') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unspaced' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('nonterritorial', 'territorial') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonterritorial' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('anemophilous', 'entomophilous') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'entomophilous' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('liveried', 'unliveried') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unliveried' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('nonruminant', 'ruminant') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonruminant' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('double-barreled', 'single-barreled') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'single-barreled' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('unwebbed', 'webbed') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unwebbed' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('immanent', 'transeunt') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'transeunt' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('nonpasserine', 'passerine') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonpasserine' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('causative', 'noncausative') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'noncausative' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('bibbed', 'bibless') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'bibless' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('metamorphic', 'nonmetamorphic') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonmetamorphic' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('inquiring', 'uninquiring') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'uninquiring' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('balconied', 'unbalconied') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unbalconied' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('calcicolous', 'calcifugous') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'calcifugous' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('apetalous', 'petalous') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'petalous' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('nonsyllabic', 'syllabic') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonsyllabic' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('ambiversive', 'introversive') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'introversive' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('adsorbent', 'nonadsorbent') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonadsorbent' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('seductive', 'unseductive') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unseductive' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('perplexed', 'unperplexed') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unperplexed' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('cismontane', 'tramontane') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'cismontane' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('de-iodinating', 'iodinating') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'iodinating' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('loamless', 'loamy') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'loamless' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('nonsubmersible', 'submersible') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonsubmersible' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('arboreal', 'nonarboreal') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonarboreal' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('bellied', 'bellyless') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'bellyless' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('endocentric', 'exocentric') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'endocentric' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('pigeon-toed', 'splayfooted') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'splayfooted' not in vocabulary"
# ...
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'undesirous' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('civilized', 'noncivilized') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'noncivilized' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('fissile', 'nonfissile') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'nonfissile' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('starchless', 'starchy') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'starchless' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('ribbed', 'ribless') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'ribless' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('bordered', 'unbordered') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unbordered' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('heterocercal', 'homocercal') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'homocercal' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('rhythmical', 'unrhythmical') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unrhythmical' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('abactinal', 'actinal') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'actinal' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('catalectic', 'hypercatalectic') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'hypercatalectic' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('brainwashed', 'unbrainwashed') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unbrainwashed' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('injectable', 'uninjectable') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'uninjectable' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('laureled', 'unlaureled') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unlaureled' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('shrinkable', 'unshrinkable') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unshrinkable' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('aplacental', 'placental') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'aplacental' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('anaclinal', 'cataclinal') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'cataclinal' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('addicted', 'unaddicted') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'unaddicted' not in vocabulary"
# 2021-11-23 21:45:12 semaxis      ERROR    ('asyndetic', 'syndetic') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis/semaxis.py", line 27, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis/core.py", line 19, in map_axis_to_vec
#     return (emb.wv[axis[1]] - emb.wv[axis[0]])
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 353, in __getitem__
#     return self.get_vector(entities)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'syndetic' not in vocabulary"

# %%
# pickle.dump(sa, open('sa_object.p', 'wb'))

# %%
# import pickle
# sa = pickle.load(open('sa_object.p', 'rb'))

# %%
df.head()
# Out:
#     sid                                               text  \
# 0  3121               But the staff was so horrible to us.
# 1  2777  To be completely fair, the only redeeming fact...
# 2  2777  To be completely fair, the only redeeming fact...
# 3  1634  The food is uniformly exceptional, with a very...
# 4  2534  Where Gabriela personaly greets you and recomm...
#
#                     aspect sentiment
# 0                  service  negative
# 1                     food  positive
# 2  anecdotes/miscellaneous  negative
# 3                     food  positive
# 4                  service  positive

# %%
df.shape
# Out:
# (3713, 4)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (3713, 4)

# %%
COLUMNS = [str(c) for c in sorted(sa.axes.keys()) if len(c) == 2]

with open("big_table_by_average.tsv", "w") as fo_a:
    fo_a.write("{}\t{}\t{}\t{}\t{}\n".format("sid", "text", "aspect", "sentiment", "\t".join(COLUMNS)))
    for loop_index, (row_index, row) in enumerate(df.iterrows()):
        to_filter = set([row['aspect'], row['aspect']+'s'])

        if loop_index % (1000) == 0:
            logger.info(loop_index)
        try:
            mean = sa.compute_document_mean_with_tf([row['text']], min_freq = 1, to_filter = to_filter)[0]
        except:
#             logger.exception()
#             break
            continue

        fo_a.write("{}\t{}\t{}\t{}\t{}\n".format(row['sid'], row['text'], row['aspect'], row['sentiment'], "\t".join([str(v) for v in mean])))
#         break
# Out:
# 2021-11-23 21:45:33 __main__     INFO     0
# 2021-11-23 21:45:37 tensorflow   WARNING  From /Users/haewoon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-11-23 21:46:00 __main__     INFO     1000
# 2021-11-23 21:46:26 __main__     INFO     2000
# 2021-11-23 21:46:49 __main__     INFO     3000

# %% [markdown]
# # second moment with corpus mean

# %%
# test
import numpy as np
df_corpus = pd.read_csv("big_table_by_average.tsv", sep="\t")
corpus_mean = np.mean(df_corpus.drop(
    columns=[c for c in df_corpus.columns if '(' not in c]).values, axis=0)
corpus_mean
# Out:
# array([ 0.01595724, -0.12854153,  0.14096514, ...,  0.0613498 ,
#        -0.12539982,  0.04118197])

# %%
COLUMNS = [str(c) for c in sorted(sa.axes.keys()) if len(c) == 2]

with open("big_table_by_second_moment_with_corpus_mean.tsv", "w") as fo_k:
    fo_k.write("{}\t{}\t{}\t{}\t{}\n".format("sid", "text", "aspect", "sentiment", "\t".join(COLUMNS)))
#     df_corpus = pd.read_csv("big_table_200k_by_average.tsv", sep="\t")
#     corpus_mean = np.mean(df_corpus.drop(
#         columns=[c for c in df_corpus.columns if '(' not in c]).as_matrix(), axis=0)
    for loop_index, (row_index, row) in enumerate(df.iterrows()):
        to_filter = set([row['aspect'], row['aspect']+'s'])
        
        if loop_index % (1000) == 0:
            logger.info(loop_index)
        try:
            sm = sa.compute_document_second_moment_with_tf([row['text']], corpus_mean, min_freq = 1, to_filter = to_filter)  
        except:
            continue

        fo_k.write("{}\t{}\t{}\t{}\t{}\n".format(row['sid'], row['text'], row['aspect'], row['sentiment'], "\t".join([str(v) for v in sm[0]])))
#         break
# Out:
# 2021-11-23 21:47:06 __main__     INFO     0
# 2021-11-23 21:47:28 __main__     INFO     1000
# 2021-11-23 21:47:52 __main__     INFO     2000
# 2021-11-23 21:48:17 __main__     INFO     3000
